# %% [markdown]
# OptionGun03_Tonka-RBDev
# Notebook created 12/07/22
# Updated 03/21/23
# Runs with OptionGunLib01. This version does not crash with enpty option chains. It captures the ticker and coninues.
# 12/14/2 - Tested and running as OptionGun03_Tonka_Prdtn
# Dev version in this notebook temporarilly until I learn how to do releases.
#
# User Notes
# 1. This program needs a user key from Darqube.com, which it uses to get real-time stock prices.
#    Go to the Darqube website get a user account and choose the free service. Then get your key.
#    Find the Dar_key line just below the "User Parameters" block in the cell below.
#    Enter it between the quotes on the line:  DAR_key = ''
#
# 2. OptionGun produces five csv files:
#      root_data.csv. This contains a list of all tickers, with real-time price at the time of execution,
#      and the netx Earnings Report date for each ticker, if available. DO NOT CHANGE THIS FILE.
#      all_options_suffix.csv. This file contains every option available for every ticker in the list.
#      best_options_short_suffix.csv. Best options (that meet criteria) with expiry < 50 days.
#      best_options_mid_suffix.csv.   Best options (that meet criteria) with 50 <= expiry < 150 days
#      best_options_long_suffix.csv.  Best options (that meet the criteria) with 150 <= expiry.
#
# 2. The parameters just under the "User Parameters" header block can be changed.
#     TICKERS. YOu can add and remove ticker symbols from this list.
#          OptionGun gets option strings and real-time prices for every ticker in this list.
#     HIDE_TICKERS. You may want to collect option info for a ticker, but not see that ticker in best_file.csv.
#     Just put the ticker to be hidden in this list.
#     FILE_ID_TAG is the suffix that OptionGun will attach to all_options and best_options. You can change it at any time.
#
# 3. OptionGun needs about 2-3 seconds to get the option string for each ticker. For 100 tickers, it will take about 5 minutes.
#
# OptionGun Structure
#
# - HEADERS and CONSTANTS
#
# - GET OPTION DATA
#        - Get real-time price data from Darqube.
#        - Get option strings from yfinance.
#        - Get ER dates from yfinance.
#        - Parse option strings into common POWMax format.
#
# 12/15/22 - Added little option guns.
# - Put_STO_Gun - Screen and select PSTO offers
# - Call_STO_Gun- Screen and select CSTO offers
# - Put_BTC_Gun - Screen and select PBTC offers
# - Call_BTC_Gun- Screen and select CBTC offers
#
# TODO 03/24/23
# - Set up OptionProfiles.csv.
# - Before each littlegun, run OptionScreener with matching optionprofile.
# - Reorganize around 4 major blocks and libraries. OptionGunLib01, TradeManagerLib01, ScorekeeperLib01, CrystalBallLib01.
# - Use import, since that worked in the little test notebook.
# - Rewrite OptiongunLib01 to use OptionGunLib01
#
# TODO 12/15/22 - Dev Notes
# 1. Convert all_options, best_options, and real-time prices to fcts. Set up calls so they can be bypassed for testing.
# 1. Complete end-to-end flow from each little option gun to output a csv file and into XLOptionBoard.
# 1. Use new column lables to split broker_report into three.
# 2. Delete fill-col headers. Replace with correct column headers.

# %%
# ****************
#
#Header and Constants
#
# *****************
# Purpose - OptionGun downlaods option strings and ER dates from yahoo yfinance.
#                It downloads real-time stock prices and company fundamental financial data from Darqube.
#                It calculates metrics for options 
#                and selects options that score the best on these metrics: POW, ARR, PctOTM, and Expiry DaysOut.
#
#   03/19/23 - Moved functions into OptionGunLib01.
#   12/05/22 - Forked version for Tonka_Prdtn.
#   11/27/22 - Remove IEX. Now using Darqube for market data. Added many more tickers, approx. 150 total.
#
# *****************
#
# USER PARAMS
# User can change these parameters as appropriate.
#
# *****************

# *****************
#
# Import Libraries
#
# *****************

import csv
import copy
import json
import numpy as np
import os
import pandas as pd
import requests   # for http requests
import scipy
from   scipy import stats
from   scipy.stats import norm
import time
import yfinance as yf

import datetime
from   datetime import datetime
from   datetime import date
from   datetime import timedelta
#from   datetime import fromtimestamp

from   dateutil.relativedelta  import relativedelta
from   yahoo_earnings_calendar import YahooEarningsCalendar

import OptionGunLib01
from   OptionGunLib01 import GetERDates
from   OptionGunLib01 import GetPrices
from   OptionGunLib01 import GetOptions
from   OptionGunLib01 import BuildOptionMetrics

import TradeManagerLib01
import ScorekeeperLib01
import CrystalBallLib01

# *****************
#
# Flow Control
#
# CHECK 3 PARAMS:  TICKERS, FILE_ID_TAG, profile
#
# *****************

update_root_data      = True  #skip WTI call if testing code. Just use synthetic WTI_dict instead.
update_root_data_ER   = False  #skip call to yahoo calendar if testing code.
update_option_data    = True  #skip calls to yfinance if testing code.


# *****************
#
# CONSTANTS
#
# *****************

# Tickers in the first two lines have a "Strong Buy" erating from the AI Quant at SeekingAlpha.com.

TICKERS = ('BSM', 'BGSF', 'CPA', 'JEF', 'STLD', 'AMR', 'UNVR', 'CVCO', 'HUBG', 'ACLS', 'ASRT', 'STAG', \
           'AFYA', 'SMCI', 'HDSN', 'VIST', 'VRNA', 'NWG', 'PINE', 'VIR', 'ASO', 'PERI', 'STRL', 'VPG', \
           'AAPL', 'ABBV', 'ACRE', 'AFL', 'ADBE', 'AIG', 'AMD', 'AMT', 'AMZN', 'AOS', 'ARCC', 'ARNC', 'AVB', 'AVGO', \
           'AZO', 'BA', 'BAC', 'BBBY', 'BIIB', 'BNTX', 'BRSP', 'CAG', 'CAT', 'CCI', 'CF', 'CL', \
           'CLX', 'CMCSA', 'CPT', 'CRM', 'CRWD', 'CSCO', 'CSX', 'CUBE', 'CVS', 'CVX', 'DAC', 'DDOG', \
           'DHI', 'DLR', 'DUK', 'DVN', 'EPAM', 'EPD', 'EPR', 'ET', 'EXPE', 'EXR', 'FAF', 'FANG', 'FDX', 'FLNG', \
           'FMS', 'FNF', 'FSLY', 'FSR', 'FYBR', 'GBX', 'GD', 'GIS', 'GLNG', 'GOOGL', 'GS', 'GSL', 'HD', 'HIW',
           'HON', 'HR', 'HRB', 'IBM', 'INTC', 'IPI', 'IRM', 'JNJ', 'JPM', 'K', 'KO', 'LADR', 'LMT', 'LOW', \
           'LRCX', 'LYB', 'MA', 'MAN', 'MCK', 'META', 'MGA', 'MLM', 'MMM', 'MMP', 'MOS', 'MPW', \
           'MRK', 'MRNA', 'MRVL', 'MSFT', 'MU', 'NFLX', 'NKE', 'NKTR', 'NMM', 'NOW', 'NRG', 'NUE', 'NVDA', \
           'OKTA', 'ON', 'ORCC', 'PACW', 'PANW', 'PFE', 'PHM', 'PII', 'PLTR', 'PNC', 'PRU', 'PSA', 'PYPL', 'QCOM', 'RC', 'RITM', \
           'RIVN', 'ROST', 'RTX', 'SB', 'SBLK', 'SBUX', 'SCHW', 'SKT', 'SNOW', 'SO', 'SPG', 'SPY', 'SRC', \
           'STWD', 'TSLA', 'TRV', 'TXN', 'TSCO', 'TSN', 'UHAL', 'UNP', 'UPS', 'USAC', 'V', 'VICI', 'VGT', 'VMW', \
           'VNOM', 'VOO', 'WEC', 'WMT', 'WSM', 'WFC', 'XOM', 'ZIM', 'ZS')

# Add tickers from BofA Top Ten Value and Growth list, and SA Quant Top 10 List
TICKERS = TICKERS + ('CEG', 'CMG', 'LLY', 'MTCH', 'PGR', 'SEDG', 'TMUS', 'URI', 'AMP', 'EXC', 'PFG', 'WDC', \
                     'DOCU', 'ASC', 'VLO', 'PD', 'MNSO', 'MOD', 'JXN')
TICKERS = set(TICKERS)

HIDE_TICKERS = ('AOS', 'FSLY', 'NOW', 'PLTR', 'TSLA', 'VNOM', 'RIVN', 'NKTR') # Keep these tickers for database, but do not show them in best_options, because you do not want to own them.  
TICKERS = ('AMZN', 'IBM') # Short ticker list for testing.

FILE_ID_TAG       = 'Test'

profile = 'POWARRMax'

DATE_FORMAT   = '%Y-%m-%d %H:%M:%S'

DAR_key = '90180f15ecc74513a01ca017eca2bb4f'

TICKER_DELAY  = 0.020  # seconds between tickers for data requests.
EXPIRY_DELAY  = 0.03
YEC_DELAY     = 0.75

MAX_DAYSOUT   = 500.0  # This constant controls how many expiry strings are downloaded. Use low # to exclude BTOS and reduce ext. calls. Hi # includes BTOS.
MIN_DAYSOUT   = 3.0

FEE_SPREAD    = 0.75     # Fee in the bid/ask range.
DAYS_TO_CHECK_ER = (1,19) #Update ER dates from yahoo on these days of the month.

call_ticker_options = pd.DataFrame()
put_ticker_options  = pd.DataFrame()
ticker_options      = pd.DataFrame() # for a single ticker
all_options         = pd.DataFrame() # includes options for all tickers. Do not use any limits or exclusions for all_options.
good_options        = pd.DataFrame() # Has rankings for CSTO options and BTOs (CBTO).
stats               = pd.DataFrame() # Not used now.
root_data           = pd.DataFrame() # persistent file used by other programs. Specifically, OptionJrnlAll spreadsheet. This programu updates it.
options_open        = pd.DataFrame() # persistent file used by OptionCloser to recommend BTC offers.
# Out:
# OptionGunLib01 runs like a top.
# TradeManagerLib01 is empty now.
# ScorekeeperLib01 is empty now.
# CrystalBallLib01 is empty now.

# %%
# *****************
# MAIN PROGRAM - Runs four major blocks.
#
# Run GetPrices.
# If market is open, run OptionGun.
# If broker positions report is in directory, run TradeManager then run Scorekeeper.
# If market is closed, run CrystalBall.
#
# Calls functions in OptionGunLib01 to get prices and option chains.
#
# 1. Get real-time price data from Darqube. Write to root_data. 
# 2. Get ER dates from Yahoo Earnings Calendar and write to root_data.
# 3. Get option strings from yfinance. Use "try" statements to skip over exp dates where call to yfinance failed.
# 4. Parse the option data fields into the common POWMax formats.
# 
# *****************

# Call lib fct to get stock price data from Darqube. 

root_data = pd.read_csv('root_data.csv')
root_data.set_index('Ticker', inplace = True, drop = True)

root_data = pd.read_csv('root_data.csv')   #Get root_data price and ER info.
root_data.set_index('Ticker', inplace = True, drop = True)
print('just read root_data')
#Use Darqube for stock price data - both market and historical.

print('start Darqube access at:  ', datetime.now(), '  Done in ',len(TICKERS) * 1.0 / 200.0, ' minutes.')

root_data = GetPrices(TICKERS, root_data, DAR_key)

print(datetime.now())

# *****************
#
# Run OptionGun Major Block if market is open.
#
# OptionGun calls function in OptionGunLib01 to get option chains.
#
# 1. Call GetERDates to update ER dates in soot_data. 
# 2. Get option chains from yfinance. Use "try" statements to skip over exp dates where call to yfinance failed.
# 3. Parse the option data fields into the common POWMax formats.
# 4.   
#
# ****************
# 1. Call Lib fct. to get ER dates from yfinance. 

if update_root_data_ER:                # skip call to YEC for ER update
    if date.today().day in DAYS_TO_CHECK_ER:
        print('Updating ER dates.')
        root_data = GetERDates(root_data, TICKERS, YEC_DELAY)

root_data.to_csv('root_data.csv')

# 2. Get option chains from yfinance. Call fct in OPtionGunLib01.

all_options = GetOptions(root_data, TICKERS, EXPIRY_DELAY, TICKER_DELAY, MAX_DAYSOUT, MIN_DAYSOUT)

# 3. Calculate additional columns for all_options

all_options = BuildOptionMetrics(all_options, FEE_SPREAD, DATE_FORMAT)

write_file = 'all_options' + FILE_ID_TAG + '.csv'
all_options.to_csv(write_file)             #From here on, all_options does not change. It is now read_only. 

# Get option_screens df and run LittleGuns
option_screens.read_csv('option_screens.csv', index_col = 0)

# Simplify all_options for use in LittleGuns
# remove temporary columns in all_options
drop_columns = ['contractSymbol', 'lastTradeDate', 'lastPrice', 'bid', 'ask', \
                'change', 'percentChange', 'callPITM', 'BidAskSpread', \
                'volume', 'openInterest', 'Quote_Time', 'Expstring', 'contractSize', 'currency']

#Removed ER daysout and ER-Expiry from drop_columns. Put them back after fixing the format problem.

all_options.drop(labels = drop_columns, axis = 1, inplace = True)
all_options = all_options[~all_options['root'].isin(HIDE_TICKERS)].copy()

LittleGuns(all_options, option_screens)
# Out:
# just read root_data
# start Darqube access at:   2023-03-24 07:49:32.842584   Done in  0.01  minutes.
# 2023-03-24 07:49:34.705668
# getting data for  AMZN  at time  2023-03-24 07:49:34.725249
# getting data for  IBM  at time  2023-03-24 07:49:41.620369
# Got all the data for all tickers. Created additional cols. time =  2023-03-24 07:49:46.257978
#      Got options for every ticker.

# %%
#**********
#
# Put_BTC_Gun_01
# Started 12/14/22
# 1. From open_options create list of open puts
# 2. Screen all_options for only each open put.
# 2.1 Find matching PBTC trade. From all_options, get last price  
# 3. Annotate the put record with ARRBE price, < 20% price, etc. 
# 4. Make recommendation - Wait, place BTC for day / GTC, at price X, Wait for price drop to close, 
#        Wait for Expiry, Wait for Assignment.
#
# Make close offer IF:
#   - matching_PBTC_fee < MIN_BID_Pct or > ARRBE (with factor)  # for profitable trades
#           or concentration too high, or ITM is low enough, or cost_basis is higher than strike, or don't want the root.               
#**********

def Put_BTC_Gun(holdings, open_options, all_options):
    # Select only Put open trades
    PBTC_trades = open_options[open_options['option_type'] == 'Put'].copy()
    PBTC_trades.reset_index(drop = True, inplace = True)
    PBTC_trades['row_num'] = PBTC_trades.index
    
    #Find matching PBTC trade in all_options
    for i in range(PBTC_trades.shape[0]):
        strike      = PBTC_trades.loc['row_num' == i, 'strike']
        expiry      = PBTC_trades.loc['row_num' == i, 'expiry']
        root        = PBTC_trades.loc['row_num' == i, 'root']
        option_type = PBTC_trades.loc['row_num' == i, 'option_type']

        matching_PBTC = all_options.np.where[((all_options['strike'] == strike) & (all_options[expiry] == expiry)) \
                                           & ((all_options['option_type'] == option_type) & (all_options['root'] == root))]
        
        # Get last price, IV, close from matching PBTC
        PBTC_trades.loc['row_num' == i, 'close_IV'] = matching_PBTC.loc[0, 'Implied Volatility']
        PBTC_trades.loc['row_num' == i, 'close_last price'] = matching_PBTC.loc[0, 'last price']
        PBTC_trades.loc['row_num' == i, 'bid_fee'] = matching_PBTC.loc[0, 'fee']
    
    #Calculate vector column values for PBTC_trades columns
    PBTC_trades['ARRBE'] = days / price
    PBTC_trades['min_close_bid'] = MIN_BID_Pct * PBTC_trades['fee']
    PBTC_trades['est_close_ARR'] = MIN_ARR_Pct * est_close_ARR

    # Add explanation.
    
    return PBTC_options

Run_PBTC = False

if Run_PBTC:
    PBTC_options = Put_BTC_Gun(holdings, best_options)
    write_file = 'PBTC_options_' + FILE_ID_TAG + '.csv'
    PBTC_options.to_csv(write_file)

# %%
#**********
#
# Call_BTC_Gun_01
# Started 12/14/22
# 1. From open_options create list of open_calls
# 2. Screen all_options for each of the open_calls
# 3. Annotate the call with ARRBE price, < 20% price, etc. 
#
#**********

def Call_BTC_Gun(holdings, all_options):
    
    return CBTC_options

Run_CBTC = False

if Run_CBTC:
    CBTC_options = Call_BTC_Gun(holdings, best_options)
    write_file = 'CBTC__options_' + FILE_ID_TAG + '.csv'
    CBTC_options.to_csv(write_file)
    
print('shot the little guns.')
print()
# Out:
# shot the little guns.

# %%
# *****************
#
# Run TradeManager Major Block if broker report is in the directory. 
#
# TradeManager calls functions in TradeManagerLib01 to update trade_log_open, trade_log_closed, and positions.
#
# 1. Call BrokerReporter to convert borker report data into PowerMax format.
# 2. Call TradeLogger to update tlo and tlc.
# 3. Call Positions to update stock positions, cost basis, and contracts available for CSTO trades.
#
# ****************

print('TradeManager is currently empty.')
# Out:
# TradeManager is currently empty.

# %%
# *****************
#
# Run ScoreKeeper Major Block if broker report is in the directory. 
#
# ScoreKeeper calls functions in TradeManagerLib01 to update trade_log_open, trade_log_closed, and positions.
#
# 1. Call BrokerReporter to convert borker report data into PowerMax format.
# 2. Call TradeLogger to update tlo and tlc.
# 3. Call Positions to update stock positions, cost basis, and contracts available for CSTO trades.
#
# ****************

print('ScoreKeeper is currently empty.')
# Out:
# ScoreKeeper is currently empty.
