# %% [markdown]
# POWERMAX_Tonka
# Notebook created 03/30/23 from OptionGun03-Tonka-Prdtn
# Last rev 08/04/23 - Replaced OptionGunLib01 with version from RB local drive.
# Uses full OptionGunLib01.py and full PowerMax01 Main
#
# User Notes
# 1. This program needs a user key from Darqube.com, which it uses to get real-time stock prices.
#    Go to the Darqube website get a user account and choose the free service. Then get your key.
#    Find the Dar_key line just below the "User Parameters" block in the cell below.
#    Enter it between the quotes on the line:  DAR_key = ''
#
#    To test the program, run a short list of tickers. At the bottom of the next cell (cell #1), find this line:
#    #TICKERS = ('QCOM', 'GOOGL', 'META', 'NVDA')
#    Delete the # at the start of the line. Now it will run with only these four tickers.
#
#    When you want to run all tickers, type the # back at the start of the line.
#
#    Occasionally one ticker hangs up, either in getting the price or getting the option string. When the program crashes,
#    read the last line before the crash. Getting price (or data) for XXXX." Simply delete the ticker XXXX from the ticker list.
#
# 2. OptionGun produces these csv files:
#      all_options_suffix.csv. This file contains every option available for every ticker in the list.
#      Put_STO_short_Tonka.csv. Best STO options that meet criteria and expiry < 50 days out.
#      Put_STO_mid_Tonka.csv.   Best STO options that meet criteria and 50 days <= expiry < 150 days out.
#      Put_STO_long_Tonka.csv   Best STO options that meet criteria and 150 days out <= expiry.
#
#      Call_STO_short_Tonka.csv. Best STO options that meet criteria and expiry < 50 days out.
#      Call_STO_mid_Tonka.csv.   Best STO options that meet criteria and 50 days <= expiry < 150 days out.
#      Call_STO_long_Tonka.csv   Best STO options that meet criteria and 150 days out <= expiry.
#
#      root_data.csv. This contains a list of all tickers, with real-time stock price at the time of execution.
#
# 3. The parameters just under the "User Parameters" header block can be changed.
#     Add and remove ticker symbols from the TICKERS = list. Enclose each ticker Follow the format shown.
#     HIDE_TICKERS. You may want to collect option info for a ticker, but not see that ticker in best_file.csv.
#     Just put the ticker to be hidden in this list.
#
# 4. PowerMax needs about 2-8 seconds to get the option string for each ticker. For 220 tickers, it will take about 15-20 minutes.

# %%
# ****************
# USER ADJUSTABLE PARAMETERS
# *****************

DAR_key = ''

TICKERS = ('AAL', 'AAPL', 'ABBV', 'ABT', 'ACLS', 'ACRE', 'AFL', 'ADBE', 'AFYA', 'AIG', 'AMD', 'ALK', 'AMGN', 'AMP', 'AMR', 'AMT', \
           'AMZN', 'AOS', 'ARCC', 'ARES', 'ARNC', 'ASC', 'ASRT', 'ASO', 'AVB', 'AVGO', 'AX', 'AZO', 'BA', 'BAC', 'BGSF', 'BIIB', \
           'BNTX', 'BRSP', 'BSM', 'CAG', 'CAT', 'CBRE', 'CCI', 'CEG', 'CF', 'CFR', 'CHPT', 'CL', 'CLX', 'CMA', 'CMCSA', 'CMG', 'CPA', \
           'CPT', 'CRM', 'CRWD', 'CSCO', 'CSX', 'CUBE', 'CVCO', 'CVS', 'CVX', 'DAC', 'DAL', 'DDOG', 'DHI', 'DLR', 'DOCU', 'DUK', \
           'DVN', 'EL', 'ENB', 'EPAM', 'EPD', 'EPR', 'ET', 'EXC', 'EXP', 'EXPE', 'EXR', 'FAF', 'FANG', 'FCNCA', 'FDX', 'FITB', 'FLNG', \
           'FMS', 'FNF', 'FSLY', 'FSR', 'FYBR', 'GBX', 'GD', 'GIS', 'GLNG', 'GOL', 'JBLU', 'GOOG', 'GOOGL', 'GS', 'GSL', 'HA', 'HD', \
           'HDSN', 'HIW', 'HON', 'HR', 'HRB', 'HUBG', 'IBM', 'INTC', 'IPI', 'IRM', 'JEF', 'JNJ', 'JPM', 'JXN', 'K', 'KBH', \
           'KEY', 'KO', 'LADR', 'LLY', 'LMT', 'LOW', 'LRCX', 'LUV', 'LYB', 'MA', 'MAN', 'MCD', 'MCK', 'MDB', 'META', 'MGA', 'MLM', \
           'MMM', 'MMP', 'MNSO', 'MOD', 'MOS', 'MPW', 'MRK', 'MRNA', 'MRVL', 'MS', 'MSFT', 'MTB', 'MTCH', 'MU', 'NFLX', 'NKE', \
           'NKTR', 'NLY', 'NMM', 'NOW', 'NRG', 'NUE', 'NVDA', 'NWG', 'NYCB', 'O', 'OKTA', 'ON', 'PAA', 'PACW', 'PANW', \
           'PB', 'PD', 'PEBO', 'PERI', 'PFE', 'PFG', 'PGR', 'PHM', 'PII', 'PINE', 'PLTR', 'PNC', 'PRU', 'PSA', 'PYPL', \
           'QCOM', 'RC', 'RILY', 'RITM', 'RIVN', 'ROST', 'T', 'RTX', 'SB', 'SBLK', 'SBUX', 'SCHW', 'SEDG', 'SKT', 'SMCI', \
           'SNOW', 'SO', 'SOFI', 'SPG', 'SPY', 'SRC', 'STAG', 'STLD', 'STRL', 'STWD', 'TBBK', 'TMUS', 'TSLA', 'TRV', 'TXN', 'TSCO', \
           'TSN', 'UAL', 'UBS', 'UHAL', 'UNP', 'UPS', 'URI', 'USAC', 'USB', 'V', 'VICI', 'VIR', 'VGT', 'VIST', \
           'VLO', 'VMW', 'VNOM', 'VOO', 'VPG', 'VRNA', 'WAL', 'WDC', 'WEC', 'WMT', 'WPC', 'WSM', 'WFC', 'XPEL', \
           'XOM', 'ZIM', 'ZION', 'ZS')



HIDE_TICKERS = ('NOW', 'PLTR', 'VNOM', 'RIVN', 'NKTR') # Keep these tickers for database, but do not show them in best_options, because you do not want to own them.  

#Short list for testing
#TICKERS = ('ET', 'EPD', 'MU', 'DVN')

# %%
# ****************
# PowerMax01 - 04/02/23.
# *****************
# Goal - PowerMax runs all four main functional blocks: TradeManager, ScoreKeeper, CrystalBall, and OptionGun. 
#
# 
#   ToDo - Move GetERDates to CrystalBall. Not part of OptionGun.
#          Delete extra columns from saved STO profiles. What went wrong with existing delete? Reconcile puts_all with Putsssa
#
#   04/04/23 - Runs, with warnings in Bullets_PSTO. Fix warnings.
#   04/02/23 - Created from OptionGun03-Bullets.
#
# *****************
#
# Import Libraries
#
# *****************

import csv
import copy
import json
import numpy as np
import os
import pandas as pd
import requests   # for http requests
import scipy
from   scipy import stats
from   scipy.stats import norm
import time
import yfinance as yf

import datetime
from   datetime import datetime
from   datetime import date
from   datetime import timedelta
#from   datetime import fromtimestamp

from   dateutil.relativedelta  import relativedelta
from   yahoo_earnings_calendar import YahooEarningsCalendar

import OptionGunLib01

#from OptionGunLib01 import GetERDates
from OptionGunLib01 import GetPrices
from OptionGunLib01 import GetOptions
from OptionGunLib01 import BuildOptionMetrics
from OptionGunLib01 import Bullets_STO

# *****************
#
# Flow Control
#
# CHECK 3 PARAMS:  TICKERS, FILE_ID_TAG, profile
#
# *****************

update_root_data       = True  #skip Darqube call for tests.
update_root_data_ER    = False  #skip call to yahoo calendar for tests. 
update_option_data     = True  #skip call to yfinance if testing code.
run_BuildOptionMetrics = update_option_data  #skip call to BuildOptionMetrics if no update of option data.


# *****************
#
# CONSTANTS
#
# *****************

print(len(TICKERS), ' tickers to analyze.')
FILE_ID_TAG       = 'Tonka'
DATE_FORMAT = '%Y-%m-%d %H:%M:%S'
DATE_TIME_FORMAT  = '%Y-%m-%d %H:%M:%S'
DATE_ONLY_FORMAT  = '%Y-%m-%d'

TICKER_DELAY  = 0.015  # seconds between tickers for data requests.
EXPIRY_DELAY  = 0.025
YEC_DELAY     = 0.75

MAX_DAYSOUT   = 500.0  # This constant controls how many expiry strings are downloaded. Use low # to exclude BTOS and reduce ext. calls. Hi # includes BTOS.
MIN_DAYSOUT   = -1.0   

FEE_SPREAD    = 0.75     # Fee in the bid/ask range.
DAYS_TO_CHECK_ER = (1,4) #Update ER dates from yahoo on these days of the month.

# *****************
#
# MAIN PROGAM STARTS HERE (next 2 cells).
# 1. If stock market closed and broker_report file in folder
#       run TradeLogManager code block in Main program.'
#       run ScoreKeeper code block in Main program.
# 2. If stock market closed run CrystalBall code block in Main program.
# 3, If stock market open run OptionGun code block in Main program.
#
# *****************
# Out:
# OptionGunLib01 runs like a top.
# 241  tickers to analyze.

# %%
# *****************
#
# TradeManager
#
# 1. If stock market closed and broker_report file in folder
#       run TradeLogManager code block in Main program.'
# 2. Run BrokerReporter if new broker_report file is in folder.
# 3. Run TradeLogger, which updates trades_open and trades_closed
# 4. Update holdings, cost basis, # contracts committed, # contracts available. All these data columns are in root_data.

# *****************
#
# ScoreKeeper
#
# 1. Run sll ScoreKeeper functions.
#
# *****************

# *****************
#
# CrystalBall
#
# 1. Update all ML features for all option profiles.
# 2. Run ScoreKeeper code block in Main program.
# 2. If stock market closed run CrystalBall code block in Main program.
# 3, If stock market open run OptionGun code block in Main program.
#
# *****************

# %%
# *****************
#
#OptionGun
#
# 1. Call GetPrices to get real-time price data from Darqube write to root_data. 
# 2. Call GetERDates to get dates from Yahoo Earnings Calendar and write to root_data.
# 3. Call GetOptions to get options data from yfinance. Use "try" statements to skip over exp dates where call to yfinance failed.
# 4. Call BuildOptionMetrics to build additional metrics fields in each option record.
# 5. Call Bullets_STO to screen all_options for each STO profile.
# FUTURE TODO
# 6. Call Bullets_BTC to build BTC trades for each open STO trade.
# 7. Call BuyWrite to screen for BuyWrite trades.
# 
# *****************

root_data = pd.read_csv('root_data.csv')   #Get root_data price and ER info.
root_data.set_index('Ticker', inplace = True, drop = True)
print('just read root_data')
#Use Darqube for stock price data - both market and historical.

print('start Darqube access at:  ', datetime.now(), '  Done in ',len(TICKERS) * 1.0 / 200.0, ' minutes.')

if update_root_data:
    root_data = GetPrices(TICKERS, root_data, DAR_key)

print(datetime.now())

if update_root_data_ER:                # skip call to YEC for ER update
    if date.today().day in DAYS_TO_CHECK_ER:
        print('Updating ER dates.')
        root_data = GetERDates(root_data, TICKERS, YEC_DELAY)

root_data.to_csv('root_data.csv')

# Get option chains
if update_option_data:
    all_options = GetOptions(root_data, TICKERS, EXPIRY_DELAY, TICKER_DELAY, MAX_DAYSOUT, MIN_DAYSOUT)
else:
    all_options = pd.read_csv('all_options_test.csv', index_col = 0)
    
#Calculate additional columns for all_options
if run_BuildOptionMetrics:
    all_options, clean_options = BuildOptionMetrics(all_options, FEE_SPREAD, HIDE_TICKERS, DATE_ONLY_FORMAT, DATE_TIME_FORMAT)
    write_file = 'all_options' + FILE_ID_TAG + '.csv'
    all_options.to_csv(write_file)
    print('Wrote all_options')
else:
    all_options = pd.read_csv('all_options_test.csv') # For testing only    


profiles = pd.read_csv('option_profiles.csv', index_col = 0)
float_columns = profiles.columns.tolist()
float_columns.remove('Active') # So, why have 'Active'? Maybe for later testing and run control?.
profiles[float_columns] = profiles[float_columns].astype(float).copy()

print('calling Bullets_STO')
Bullets_STO(clean_options, profiles)
print('Bullets_STO ran all the way.')
# Out:
# just read root_data
# start Darqube access at:   2023-08-05 10:06:46.510441   Done in  1.205  minutes.
# getting price for  AAL
# getting price for  AAPL
# getting price for  ABBV
# getting price for  ABT
# getting price for  ACLS
# getting price for  ACRE
# getting price for  AFL
# getting price for  ADBE
# getting price for  AFYA
# getting price for  AIG
# getting price for  AMD
# getting price for  ALK
# getting price for  AMGN
# getting price for  AMP
# getting price for  AMR
# getting price for  AMT
# getting price for  AMZN
# getting price for  AOS
# getting price for  ARCC
# getting price for  ARES
# getting price for  ARNC
# getting price for  ASC
# getting price for  ASRT
# getting price for  ASO
# getting price for  AVB
# getting price for  AVGO
# getting price for  AX
# getting price for  AZO
# getting price for  BA
# getting price for  BAC
# getting price for  BGSF
# getting price for  BIIB
# getting price for  BNTX
# getting price for  BRSP
# getting price for  BSM
# getting price for  CAG
# getting price for  CAT
# getting price for  CBRE
# getting price for  CCI
# getting price for  CEG
# getting price for  CF
# getting price for  CFR
# getting price for  CHPT
# getting price for  CL
# getting price for  CLX
# getting price for  CMA
# getting price for  CMCSA
# getting price for  CMG
# getting price for  CPA
# getting price for  CPT
# getting price for  CRM
# getting price for  CRWD
# getting price for  CSCO
# getting price for  CSX
# getting price for  CUBE
# getting price for  CVCO
# getting price for  CVS
# getting price for  CVX
# getting price for  DAC
# getting price for  DAL
# getting price for  DDOG
# getting price for  DHI
# getting price for  DLR
# getting price for  DOCU
# getting price for  DUK
# getting price for  DVN
# getting price for  EL
# getting price for  ENB
# getting price for  EPAM
# getting price for  EPD
# getting price for  EPR
# getting price for  ET
# getting price for  EXC
# getting price for  EXP
# getting price for  EXPE
# getting price for  EXR
# getting price for  FAF
# getting price for  FANG
# getting price for  FCNCA
# getting price for  FDX
# getting price for  FITB
# getting price for  FLNG
# getting price for  FMS
# getting price for  FNF
# getting price for  FSLY
# getting price for  FSR
# getting price for  FYBR
# getting price for  GBX
# getting price for  GD
# getting price for  GIS
# getting price for  GLNG
# getting price for  GOL
# getting price for  JBLU
# getting price for  GOOG
# getting price for  GOOGL
# getting price for  GS
# getting price for  GSL
# getting price for  HA
# getting price for  HD
# getting price for  HDSN
# getting price for  HIW
# getting price for  HON
# getting price for  HR
# getting price for  HRB
# getting price for  HUBG
# getting price for  IBM
# getting price for  INTC
# getting price for  IPI
# getting price for  IRM
# getting price for  JEF
# getting price for  JNJ
# getting price for  JPM
# getting price for  JXN
# getting price for  K
# getting price for  KBH
# getting price for  KEY
# getting price for  KO
# getting price for  LADR
# getting price for  LLY
# getting price for  LMT
# getting price for  LOW
# getting price for  LRCX
# getting price for  LUV
# getting price for  LYB
# getting price for  MA
# getting price for  MAN
# getting price for  MCD
# getting price for  MCK
# getting price for  MDB
# getting price for  META
# getting price for  MGA
# getting price for  MLM
# getting price for  MMM
# getting price for  MMP
# getting price for  MNSO
# getting price for  MOD
# getting price for  MOS
# getting price for  MPW
# getting price for  MRK
# getting price for  MRNA
# getting price for  MRVL
# getting price for  MS
# getting price for  MSFT
# getting price for  MTB
# getting price for  MTCH
# getting price for  MU
# getting price for  NFLX
# getting price for  NKE
# getting price for  NKTR
# getting price for  NLY
# getting price for  NMM
# getting price for  NOW
# getting price for  NRG
# getting price for  NUE
# getting price for  NVDA
# getting price for  NWG
# getting price for  NYCB
# getting price for  O
# getting price for  OKTA
# getting price for  ON
# getting price for  PAA
# getting price for  PACW
# getting price for  PANW
# getting price for  PB
# getting price for  PD
# getting price for  PEBO
# getting price for  PERI
# getting price for  PFE
# getting price for  PFG
# getting price for  PGR
# getting price for  PHM
# getting price for  PII
# getting price for  PINE
# getting price for  PLTR
# getting price for  PNC
# getting price for  PRU
# getting price for  PSA
# getting price for  PYPL
# getting price for  QCOM
# getting price for  RC
# getting price for  RILY
# getting price for  RITM
# getting price for  RIVN
# getting price for  ROST
# getting price for  T
# getting price for  RTX
# getting price for  SB
# getting price for  SBLK
# getting price for  SBUX
# getting price for  SCHW
# getting price for  SEDG
# getting price for  SKT
# getting price for  SMCI
# getting price for  SNOW
# getting price for  SO
# getting price for  SOFI
# getting price for  SPG
# getting price for  SPY
# getting price for  SRC
# getting price for  STAG
# getting price for  STLD
# getting price for  STRL
# getting price for  STWD
# getting price for  TBBK
# getting price for  TMUS
# getting price for  TSLA
# getting price for  TRV
# getting price for  TXN
# getting price for  TSCO
# getting price for  TSN
# getting price for  UAL
# getting price for  UBS
# getting price for  UHAL
# getting price for  UNP
# getting price for  UPS
# getting price for  URI
# getting price for  USAC
# getting price for  USB
# getting price for  V
# getting price for  VICI
# getting price for  VIR
# getting price for  VGT
# getting price for  VIST
# getting price for  VLO
# getting price for  VMW
# getting price for  VNOM
# getting price for  VOO
# getting price for  VPG
# getting price for  VRNA
# getting price for  WAL
# getting price for  WDC
# getting price for  WEC
# getting price for  WMT
# getting price for  WPC
# getting price for  WSM
# getting price for  WFC
# getting price for  XPEL
# getting price for  XOM
# getting price for  ZIM
# getting price for  ZION
# getting price for  ZS
# 2023-08-05 10:09:30.051322
# getting data for  AAL  at time  2023-08-05 10:09:30.068734
# getting data for  AAPL  at time  2023-08-05 10:09:34.242881
# getting data for  ABBV  at time  2023-08-05 10:09:39.541765
# getting data for  ABT  at time  2023-08-05 10:09:44.041301
# getting data for  ACLS  at time  2023-08-05 10:09:48.293830
# getting data for  ACRE  at time  2023-08-05 10:09:50.979656
# getting data for  AFL  at time  2023-08-05 10:09:52.437123
# getting data for  ADBE  at time  2023-08-05 10:09:56.158868
# getting data for  AFYA  at time  2023-08-05 10:10:00.577777
# getting data for  AIG  at time  2023-08-05 10:10:01.738852
# getting data for  AMD  at time  2023-08-05 10:10:05.713923
# getting data for  ALK  at time  2023-08-05 10:10:11.186613
# getting data for  AMGN  at time  2023-08-05 10:11:43.310664
# getting data for  AMP  at time  2023-08-05 10:11:46.989077
# getting data for  AMR  at time  2023-08-05 10:11:48.927349
# getting data for  AMT  at time  2023-08-05 10:11:51.280948
# getting data for  AMZN  at time  2023-08-05 10:11:53.339953
# getting data for  AOS  at time  2023-08-05 10:12:00.150487
# getting data for  ARCC  at time  2023-08-05 10:12:02.003739
# getting data for  ARES  at time  2023-08-05 10:12:04.011867
# getting data for  ARNC  at time  2023-08-05 10:12:05.586052
# getting data for  ASC  at time  2023-08-05 10:12:07.562997
# getting data for  ASRT  at time  2023-08-05 10:12:09.052302
# getting data for  ASO  at time  2023-08-05 10:12:11.001250
# getting data for  AVB  at time  2023-08-05 10:12:14.431685
# getting data for  AVGO  at time  2023-08-05 10:12:16.494971
# getting data for  AX  at time  2023-08-05 10:12:21.757507
# getting data for  AZO  at time  2023-08-05 10:12:23.776362
# getting data for  BA  at time  2023-08-05 10:12:26.119329
# getting data for  BAC  at time  2023-08-05 10:12:30.701381
# getting data for  BGSF  at time  2023-08-05 10:12:36.177815
# getting data for  BIIB  at time  2023-08-05 10:12:37.747764
# getting data for  BNTX  at time  2023-08-05 10:12:41.542966
# getting data for  BRSP  at time  2023-08-05 10:12:44.128032
# getting data for  BSM  at time  2023-08-05 10:12:45.936897
# getting data for  CAG  at time  2023-08-05 10:12:47.809720
# getting data for  CAT  at time  2023-08-05 10:12:51.213912
# getting data for  CBRE  at time  2023-08-05 10:12:55.760826
# getting data for  CCI  at time  2023-08-05 10:12:58.109096
# getting data for  CEG  at time  2023-08-05 10:12:59.807346
# getting data for  CF  at time  2023-08-05 10:13:02.656582
# getting data for  CFR  at time  2023-08-05 10:13:07.060953
# getting data for  CHPT  at time  2023-08-05 10:13:09.167345
# getting data for  CL  at time  2023-08-05 10:13:12.978523
# getting data for  CLX  at time  2023-08-05 10:13:15.392329
# getting data for  CMA  at time  2023-08-05 10:13:18.908789
# getting data for  CMCSA  at time  2023-08-05 10:13:22.555006
# getting data for  CMG  at time  2023-08-05 10:13:25.902773
# getting data for  CPA  at time  2023-08-05 10:13:30.660158
# getting data for  CPT  at time  2023-08-05 10:13:32.206629
# getting data for  CRM  at time  2023-08-05 10:13:33.758331
# getting data for  CRWD  at time  2023-08-05 10:13:38.179882
# getting data for  CSCO  at time  2023-08-05 10:13:42.447837
# getting data for  CSX  at time  2023-08-05 10:13:46.554525
# getting data for  CUBE  at time  2023-08-05 10:13:50.135274
# getting data for  CVCO  at time  2023-08-05 10:13:52.047087
# getting data for  CVS  at time  2023-08-05 10:13:53.579033
# getting data for  CVX  at time  2023-08-05 10:13:57.708765
# getting data for  DAC  at time  2023-08-05 10:14:02.048077
# getting data for  DAL  at time  2023-08-05 10:14:03.612079
# getting data for  DDOG  at time  2023-08-05 10:14:07.912928
# getting data for  DHI  at time  2023-08-05 10:14:12.167159
# getting data for  DLR  at time  2023-08-05 10:14:15.973413
# getting data for  DOCU  at time  2023-08-05 10:14:19.540613
# getting data for  DUK  at time  2023-08-05 10:14:24.621931
# getting data for  DVN  at time  2023-08-05 10:14:26.500300
# getting data for  EL  at time  2023-08-05 10:14:30.537305
# getting data for  ENB  at time  2023-08-05 10:14:33.461206
# getting data for  EPAM  at time  2023-08-05 10:14:35.371554
# getting data for  EPD  at time  2023-08-05 10:14:36.971623
# getting data for  EPR  at time  2023-08-05 10:14:40.640737
# getting data for  ET  at time  2023-08-05 10:14:42.128295
# getting data for  EXC  at time  2023-08-05 10:14:48.386663
# getting data for  EXP  at time  2023-08-05 10:14:50.453546
# getting data for  EXPE  at time  2023-08-05 10:14:52.368698
# getting data for  EXR  at time  2023-08-05 10:14:56.195494
# getting data for  FAF  at time  2023-08-05 10:14:57.761462
# getting data for  FANG  at time  2023-08-05 10:14:59.339678
# getting data for  FCNCA  at time  2023-08-05 10:15:01.731576
# getting data for  FDX  at time  2023-08-05 10:15:03.531115
# getting data for  FITB  at time  2023-08-05 10:15:07.168468
# getting data for  FLNG  at time  2023-08-05 10:15:10.979749
# getting data for  FMS  at time  2023-08-05 10:15:12.935425
# getting data for  FNF  at time  2023-08-05 10:15:14.134050
# getting data for  FSLY  at time  2023-08-05 10:15:15.623383
# getting data for  FSR  at time  2023-08-05 10:15:19.894811
# getting data for  FYBR  at time  2023-08-05 10:15:24.448387
# getting data for  GBX  at time  2023-08-05 10:15:26.327573
# getting data for  GD  at time  2023-08-05 10:15:28.171546
# getting data for  GIS  at time  2023-08-05 10:15:32.160016
# getting data for  GLNG  at time  2023-08-05 10:15:34.177849
# getting data for  GOL  at time  2023-08-05 10:15:36.042889
# getting data for  JBLU  at time  2023-08-05 10:15:37.561246
# getting data for  GOOG  at time  2023-08-05 10:15:41.043998
# getting data for  GOOGL  at time  2023-08-05 10:15:46.712865
# getting data for  GS  at time  2023-08-05 10:15:52.864109
# getting data for  GSL  at time  2023-08-05 10:15:58.357283
# getting data for  HA  at time  2023-08-05 10:16:00.288992
# getting data for  HD  at time  2023-08-05 10:16:01.932542
# getting data for  HDSN  at time  2023-08-05 10:16:06.841159
# getting data for  HIW  at time  2023-08-05 10:16:08.401537
# getting data for  HON  at time  2023-08-05 10:16:09.972515
# getting data for  HR  at time  2023-08-05 10:16:13.765306
# getting data for  HRB  at time  2023-08-05 10:16:15.244500
# getting data for  HUBG  at time  2023-08-05 10:16:17.325734
# getting data for  IBM  at time  2023-08-05 10:16:18.878284
# getting data for  INTC  at time  2023-08-05 10:16:23.155241
# getting data for  IPI  at time  2023-08-05 10:20:45.428105
# getting data for  IRM  at time  2023-08-05 10:20:46.942261
# getting data for  JEF  at time  2023-08-05 10:20:48.501282
# getting data for  JNJ  at time  2023-08-05 10:20:50.646635
# getting data for  JPM  at time  2023-08-05 10:20:54.551652
# getting data for  JXN  at time  2023-08-05 10:21:02.543728
# getting data for  K  at time  2023-08-05 10:21:04.566213
# getting data for  KBH  at time  2023-08-05 10:21:06.570857
# getting data for  KEY  at time  2023-08-05 10:21:10.098192
# getting data for  KO  at time  2023-08-05 10:21:14.205247
# getting data for  LADR  at time  2023-08-05 10:21:18.917014
# getting data for  LLY  at time  2023-08-05 10:21:20.472202
# getting data for  LMT  at time  2023-08-05 10:21:24.475141
# getting data for  LOW  at time  2023-08-05 10:21:28.504114
# getting data for  LRCX  at time  2023-08-05 10:21:32.005333
# getting data for  LUV  at time  2023-08-05 10:21:37.083289
# getting data for  LYB  at time  2023-08-05 10:21:40.823918
# getting data for  MA  at time  2023-08-05 10:21:43.122335
# getting data for  MAN  at time  2023-08-05 10:21:47.294405
# getting data for  MCD  at time  2023-08-05 10:21:48.872284
# getting data for  MCK  at time  2023-08-05 10:21:53.606354
# getting data for  MDB  at time  2023-08-05 10:21:57.323142
# getting data for  META  at time  2023-08-05 10:22:01.961440
# getting data for  MGA  at time  2023-08-05 10:22:08.440914
# getting data for  MLM  at time  2023-08-05 10:22:10.384170
# getting data for  MMM  at time  2023-08-05 10:22:13.173486
# getting data for  MMP  at time  2023-08-05 10:22:17.244937
# getting data for  MNSO  at time  2023-08-05 10:22:18.891810
# getting data for  MOD  at time  2023-08-05 10:22:20.564409
# getting data for  MOS  at time  2023-08-05 10:22:22.094915
# getting data for  MPW  at time  2023-08-05 10:22:26.387963
# getting data for  MRK  at time  2023-08-05 10:22:29.873081
# getting data for  MRNA  at time  2023-08-05 10:22:33.627007
# getting data for  MRVL  at time  2023-08-05 10:22:38.357052
# getting data for  MS  at time  2023-08-05 10:22:42.741910
# getting data for  MSFT  at time  2023-08-05 10:22:47.776000
# getting data for  MTB  at time  2023-08-05 10:22:54.016858
# getting data for  MTCH  at time  2023-08-05 10:22:56.435067
# getting data for  MU  at time  2023-08-05 10:23:00.263334
# getting data for  NFLX  at time  2023-08-05 10:23:04.978289
# getting data for  NKE  at time  2023-08-05 10:23:11.287139
# getting data for  NKTR  at time  2023-08-05 10:23:15.603870
# getting data for  NLY  at time  2023-08-05 10:23:17.103232
# getting data for  NMM  at time  2023-08-05 10:23:20.625801
# getting data for  NOW  at time  2023-08-05 10:23:22.431181
# getting data for  NRG  at time  2023-08-05 10:23:26.897886
# getting data for  NUE  at time  2023-08-05 10:23:29.391798
# getting data for  NVDA  at time  2023-08-05 10:23:33.202509
# getting data for  NWG  at time  2023-08-05 10:23:40.384971
# getting data for  NYCB  at time  2023-08-05 10:23:41.906490
# getting data for  O  at time  2023-08-05 10:23:47.284487
# getting data for  OKTA  at time  2023-08-05 10:23:49.819534
# getting data for  ON  at time  2023-08-05 10:23:53.753765
# getting data for  PAA  at time  2023-08-05 10:23:58.775716
# getting data for  PACW  at time  2023-08-05 10:24:02.363498
# getting data for  PANW  at time  2023-08-05 10:24:06.276042
# getting data for  PB  at time  2023-08-05 10:24:10.325830
# getting data for  PD  at time  2023-08-05 10:24:11.945359
# getting data for  PEBO  at time  2023-08-05 10:24:14.221486
# getting data for  PERI  at time  2023-08-05 10:24:15.383948
# getting data for  PFE  at time  2023-08-05 10:24:17.393153
# getting data for  PFG  at time  2023-08-05 10:24:21.488776
# getting data for  PGR  at time  2023-08-05 10:24:23.403326
# getting data for  PHM  at time  2023-08-05 10:24:25.427685
# getting data for  PII  at time  2023-08-05 10:26:33.727772
# getting data for  PINE  at time  2023-08-05 10:26:35.835306
# getting data for  PLTR  at time  2023-08-05 10:26:37.375436
# getting data for  PNC  at time  2023-08-05 10:26:42.487000
# getting data for  PRU  at time  2023-08-05 10:26:46.822046
# getting data for  PSA  at time  2023-08-05 10:26:49.230880
# getting data for  PYPL  at time  2023-08-05 10:26:51.218573
# getting data for  QCOM  at time  2023-08-05 10:26:55.586843
# getting data for  RC  at time  2023-08-05 10:26:59.507337
# getting data for  RILY  at time  2023-08-05 10:27:01.105034
# getting data for  RITM  at time  2023-08-05 10:27:03.054254
# getting data for  RIVN  at time  2023-08-05 10:27:05.522235
# getting data for  ROST  at time  2023-08-05 10:27:09.800001
# getting data for  T  at time  2023-08-05 10:27:13.991403
# getting data for  RTX  at time  2023-08-05 10:27:17.931619
# getting data for  SB  at time  2023-08-05 10:27:21.947850
# getting data for  SBLK  at time  2023-08-05 10:27:23.473068
# getting data for  SBUX  at time  2023-08-05 10:27:26.932648
# getting data for  SCHW  at time  2023-08-05 10:27:30.666360
# getting data for  SEDG  at time  2023-08-05 10:27:35.156659
# getting data for  SKT  at time  2023-08-05 10:27:41.854362
# getting data for  SMCI  at time  2023-08-05 10:27:44.090903
# getting data for  SNOW  at time  2023-08-05 10:27:48.988657
# getting data for  SO  at time  2023-08-05 10:27:54.191806
# getting data for  SOFI  at time  2023-08-05 10:27:57.932268
# getting data for  SPG  at time  2023-08-05 10:28:02.457026
# getting data for  SPY  at time  2023-08-05 10:28:04.456979
# getting data for  SRC  at time  2023-08-05 10:28:14.853710
# getting data for  STAG  at time  2023-08-05 10:28:16.448924
# getting data for  STLD  at time  2023-08-05 10:28:18.019828
# getting data for  STRL  at time  2023-08-05 10:28:20.100847
# getting data for  STWD  at time  2023-08-05 10:28:21.773386
# getting data for  TBBK  at time  2023-08-05 10:28:24.767716
# getting data for  TMUS  at time  2023-08-05 10:28:26.209759
# getting data for  TSLA  at time  2023-08-05 10:28:30.191663
# getting data for  TRV  at time  2023-08-05 10:28:37.044967
# getting data for  TXN  at time  2023-08-05 10:28:39.030571
# getting data for  TSCO  at time  2023-08-05 10:28:42.846059
# getting data for  TSN  at time  2023-08-05 10:28:46.352698
# getting data for  UAL  at time  2023-08-05 10:28:49.868080
# getting data for  UBS  at time  2023-08-05 10:28:54.598569
# getting data for  UHAL  at time  2023-08-05 10:28:56.846949
# getting data for  UNP  at time  2023-08-05 10:28:58.363548
# getting data for  UPS  at time  2023-08-05 10:29:09.033473
# getting data for  URI  at time  2023-08-05 10:29:13.068954
# getting data for  USAC  at time  2023-08-05 10:29:17.451312
# getting data for  USB  at time  2023-08-05 10:29:18.999368
# getting data for  V  at time  2023-08-05 10:29:23.081451
# getting data for  VICI  at time  2023-08-05 10:29:26.945706
# getting data for  VIR  at time  2023-08-05 10:29:28.867140
# getting data for  VGT  at time  2023-08-05 10:29:30.749901
# getting data for  VIST  at time  2023-08-05 10:29:35.932055
# getting data for  VLO  at time  2023-08-05 10:29:37.550185
# getting data for  VMW  at time  2023-08-05 10:29:41.446316
# getting data for  VNOM  at time  2023-08-05 10:29:43.562838
# getting data for  VOO  at time  2023-08-05 10:29:45.216372
# getting data for  VPG  at time  2023-08-05 10:29:47.871006
# getting data for  VRNA  at time  2023-08-05 10:29:49.050584
# getting data for  WAL  at time  2023-08-05 10:29:50.967402
# getting data for  WDC  at time  2023-08-05 10:29:54.974830
# getting data for  WEC  at time  2023-08-05 10:29:58.491524
# getting data for  WMT  at time  2023-08-05 10:30:00.156149
# getting data for  WPC  at time  2023-08-05 10:30:04.534756
# getting data for  WSM  at time  2023-08-05 10:30:06.083385
# getting data for  WFC  at time  2023-08-05 10:30:09.634268
# getting data for  XPEL  at time  2023-08-05 10:30:14.313590
# getting data for  XOM  at time  2023-08-05 10:30:15.972272
# getting data for  ZIM  at time  2023-08-05 10:30:19.614029
# getting data for  ZION  at time  2023-08-05 10:30:22.634232
# getting data for  ZS  at time  2023-08-05 10:30:26.485520
# Got all the data for all tickers. Created additional cols. time =  2023-08-05 10:30:31.049692
#      Got options for every ticker.
# clean_options.csv
# Wrote all_options
# calling Bullets_STO
# Wrote  Put_STO_Short  at  2023-08-05 10:35:06.489495
# Wrote  Put_STO_Mid  at  2023-08-05 10:35:06.504118
# Wrote  Put_STO_Long  at  2023-08-05 10:35:06.536986
# Wrote  Call_STO_Short  at  2023-08-05 10:35:06.567337
# Wrote  Call_STO_Mid  at  2023-08-05 10:35:06.567337
# Wrote  Call_STO_Long  at  2023-08-05 10:35:06.614229
# Bullets_STO ran all the way.
